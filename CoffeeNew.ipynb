# %%
# Define variable
def menu():
        print('**', ' ' * 29, 'Water : ', ww)
        print('**', ' ' * 29, 'Milk  : ', mm )
        print('**', ' ' * 29, 'Coffee: ', cf)
        print('**', ' ' * 29, 'Cup : ', cc)
        print('**', ' ' * 29, 'Money : ', mn)
ww = 400
mm = 540
cf = 120
cc = 9
mn = 550
y = 1
tp = 0
status = True
i = 0
print('Well Come !')
print('Coffee Shop')
while True:
    tp = (input('buy, fill, take , remaining, exit: '))
    b = tp
    if 'buy' in b:
        print('**', ' ' * 29, '1.Espresso', ' ' * 33)
        print('**', ' ' * 29, '2.Latte', ' ' * 36)
        print('**', ' ' * 29, '3.Cappuccino', ' ' * 31)      
        while True:
            c = input('enter 1 or 2 or 3 : ')
            if '1' in c:
                if ww - 250 >= 0:
                    if cf - 16 >= 0:
                        if cc - 1 >= 0:
                            if mn - 4 >= 0:
                                print('I have enough resources, making you a coffee!')
                                ww -= 350
                                cf -= 16
                                cc -= 1
                                mn -= 4
                elif ww - 350 < 0:
                    print('Sorry, not enough water!')
                elif cf - 16 < 0:
                    print('Sorry, not enough coffee beans!')
                elif cc - 1 < 0:
                    print('Sorry, not enough water cup!')
                elif mn - 4 < 0:
                    print('Sorry, not enough money!')
                break
            elif '2' in c:
                if ww - 350 >= 0:
                    if mm - 75 >= 0:
                        if cf - 20 >= 0:
                            if cc - 1 >= 0:
                                if mn - 7 >= 0:
                                    print('I have enough resources, making you a coffee!')
                                    ww -= 350
                                    mm -= 75
                                    cf -= 20
                                    cc -= 1
                                    mn -=7
                elif ww - 350 < 0:
                    print('Sorry, not enough water!')
                elif cf - 20 < 0:
                    print('Sorry, not enough coffee beans!')
                elif cc - 1 < 0:
                    print('Sorry, not enough water cup!')
                elif mn - 7 < 0:
                    print('Sorry, not enough money!')
                elif mm - 75 < 0:
                    print('Sorry, not enough milk!')
                break
            elif '3' in c:
                if ww - 200 >= 0:
                    if cf - 12 >= 0:
                        if cc - 1 >= 0:
                            if mm - 100 >= 0:
                                if mn - 6 >= 0:
                                    print('I have enough resources, making you a coffee!')
                                    ww -= 200
                                    mm -= 100
                                    cf -= 12
                                    cc -= 1
                                    mn -= 6
                elif ww - 200 < 0:
                    print('Sorry, not enough water!')
                elif cf - 12 < 0:
                    print('Sorry, not enough coffee beans!')
                elif cc - 1 < 0:
                    print('Sorry, not enough water cup!')
                elif mm - 100 < 0:
                    print('Sorry, not enough milk!')
                elif mn - 6 < 0:
                    print('Sorry, not enough money!')
                break
            else:
                print('enter again')

    elif 'fill' in b:
        ww1 = int(input('add water: '))
        ww += ww1
        mm1 = int(input('add milk: '))
        mm += mn1
        cf1 = int(input('add coffee: '))
        cf += cf1
        cc1 = int(input('add cup: '))
        cc += cc1
        print('**', ' ' * 29, 'Water : ', ww)
        print('**', ' ' * 29, 'Milk  : ', mm )
        print('**', ' ' * 29, 'Coffee: ', cf)
        print('**', ' ' * 29, 'Cappu : ', cc)
        print('**', ' ' * 29, 'Money : ', mn)

    elif 'take' in b:
        tp = int(input('I gave you $'))
        mn += tp
        menu()

    elif 'remaining' in b:
        menu()
        
    elif 'exit' in b:
        break
    
    else:
        print('You entered the wrong Please enter again')
# Out:
# Well Come !
# Coffee Shop
# buy, fill, take , remaining, exit: Exit
# You entered the wrong Please enter again
# buy, fill, take , remaining, exit: exit
